# %%
import requests
from bs4 import BeautifulSoup

# %%
url = raw_input("Enter a website to extract the URL's from: ")
r  = requests.get("http://" +url)

data = r.text

soup = BeautifulSoup(data)

for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# Enter a website to extract the URL's from: www.youtube.com/watch?v=lWA2pjMjpBs
# /redirect?event=gcookie&q=https%3A%2F%2Fwww.google.fr%2Fintl%2Ffr%2Fpolicies%2Ftechnologies%2Fcookies&usg=6Z3uUBNV8CoMzzGSYvItbY846NA=
# /
# //www.youtube.com/upload
# //support.google.com/youtube/answer/1738660?hl=en
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# /user/RihannaVEVO
# /channel/UC2xskkQVFEpLcGFnNSLQY0A
# https://accounts.google.com/ServiceLogin?uilel=3&service=youtube&passive=true&hl=fr&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3D__FEATURE__%26hl%3Dfr%26next%3D%252Fwatch%253Fv%253DlWA2pjMjpBs%26action_handle_signin%3Dtrue%26app%3Ddesktop
# https://accounts.google.com/ServiceLogin?uilel=3&service=youtube&passive=true&hl=fr&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3D__FEATURE__%26hl%3Dfr%26next%3D%252Fwatch%253Fv%253DlWA2pjMjpBs%26action_handle_signin%3Dtrue%26app%3Ddesktop
# https://accounts.google.com/ServiceLogin?uilel=3&service=youtube&passive=true&hl=fr&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3D__FEATURE__%26hl%3Dfr%26next%3D%252Fwatch%253Fv%253DlWA2pjMjpBs%26action_handle_signin%3Dtrue%26app%3Ddesktop
# https://accounts.google.com/ServiceLogin?uilel=3&service=youtube&passive=true&hl=fr&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3D__FEATURE__%26hl%3Dfr%26next%3D%252Fwatch%253Fv%253DlWA2pjMjpBs%26action_handle_signin%3Dtrue%26app%3Ddesktop
# http://smarturl.it/UnapologeticDlx
# http://www.vevo.com/watch/USUV71201766?utm_source=youtube&utm_medium=description&utm_campaign=ytd
# /channel/UCvWtix2TtWGe9kffqnwdaMw
# https://www.youtube.com/cthru?key=AE_82Td6OyNUyW8mc696v6VH6lNt6LIh1xlHByaaur3FWZIfMbkxaHewoZTKnzHtYbgypG17x9rNSeFGI6xemeBnptveIvv9dlDnb0rBudZ3csdXaArQEsiwsYn0RiFWasHfwarvh06W9otazt-jLhI36wYeNJvPl4wK08_dxSHYHITb5lhq4qo1KPbrs6ZNL35UnRziR-wd&v=lWA2pjMjpBs&c2b=itunes&version=2
# /channel/UC-9-kyTW8ZkZNDHQJ6FgpwQ
# http://www.youtube.com/attribution?v=lWA2pjMjpBs
# /watch?v=tg00YEETFzg
# /watch?v=tg00YEETFzg
# /watch?v=lWA2pjMjpBs&list=RDlWA2pjMjpBs
# /watch?v=sEhy-RXkNo0
# /watch?v=sEhy-RXkNo0
# /watch?v=ZQ2nCGawrSY
# /watch?v=ZQ2nCGawrSY
# /watch?v=CvBfHwUxHIk
# /watch?v=CvBfHwUxHIk
# /watch?v=2vjPBrBU-TM
# /watch?v=2vjPBrBU-TM
# /watch?v=fWNaR-rxAic
# /watch?v=fWNaR-rxAic
# /watch?v=YqeW9_5kURI&list=PLMC9KNkIncKtPzgY-5rmhvj7fax8fdxoj
# /watch?v=-YICuUtkjlg
# /watch?v=-YICuUtkjlg
# /watch?v=uelHwf8o7_U
# /watch?v=uelHwf8o7_U
# /watch?v=J91ti_MpdHA
# /watch?v=J91ti_MpdHA
# /watch?v=HBxt_v0WF6Y
# /watch?v=HBxt_v0WF6Y
# /watch?v=rp4UwPZfRis
# /watch?v=rp4UwPZfRis
# /watch?v=rYEDA3JcQqw
# /watch?v=rYEDA3JcQqw
# /watch?v=QK8mJJJvaes
# /watch?v=QK8mJJJvaes
# /watch?v=pa14VNsdSYM
# /watch?v=pa14VNsdSYM
# /watch?v=ehcVomMexkY
# /watch?v=ehcVomMexkY
# /watch?v=CevxZvSJLk8
# /watch?v=CevxZvSJLk8
# /watch?v=E1mU6h4Xdxc
# /watch?v=E1mU6h4Xdxc
# /watch?v=vr1VMr28ldo
# /watch?v=vr1VMr28ldo
# /
# /feed/history
# //www.youtube.com/yt/about/fr/
# //www.youtube.com/yt/press/fr/
# //www.youtube.com/yt/copyright/fr/
# //www.youtube.com/yt/creators/fr/
# //www.youtube.com/yt/advertise/fr/
# //www.youtube.com/yt/dev/fr/
# https://plus.google.com/+youtube
# /t/terms
# https://www.google.fr/intl/fr/policies/privacy/
# //www.youtube.com/yt/policyandsafety/fr/
# //support.google.com/youtube/?hl=fr
# /testtube
# https://accounts.google.com/ServiceLogin?uilel=3&service=youtube&passive=true&hl=fr&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3Dplaylist%26hl%3Dfr%26next%3D%252Fwatch%253Fv%253DlWA2pjMjpBs%26action_handle_signin%3Dtrue%26app%3Ddesktop

# %%
url = 'https://www.youtube.com/watch?v=lWA2pjMjpBs'
request = requests.get(url)
soup = BeautifulSoup(request.text,'html.parser')
for p in soup.find_all('a'):
    print p.get("title")
# Out:
# Accueil YouTube
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# http://smarturl.it/UnapologeticDlx
# http://www.vevo.com/watch/USUV71201766?utm_source=youtube&utm_medium=description&utm_campaign=ytd
# None
# None
# None
# None
# Rihanna - We Found Love ft. Calvin Harris
# None
# None
# Rihanna - Man Down
# None
# Rihanna - Russian Roulette
# None
# Rihanna - Umbrella (Orange Version) ft. JAY-Z
# None
# Sia - Chandelier (Official Video)
# None
# Carly Rae Jepsen - Call Me Maybe
# None
# None
# Miley Cyrus - Wrecking Ball (Director's Cut)
# None
# Eminem - Love The Way You Lie ft. Rihanna
# None
# Alicia Keys - Girl on Fire
# None
# Rihanna - Where Have You Been
# None
# Rihanna - Unfaithful
# None
# Adele - Rolling in the Deep
# None
# MACKLEMORE & RYAN LEWIS - THRIFT SHOP FEAT. WANZ (OFFICIAL VIDEO)
# None
# Rihanna - Only Girl (In The World)
# None
# Rihanna - Pour It Up (Explicit)
# None
# Katy Perry - Roar (Official)
# None
# Rihanna - Disturbia
# None
# Rihanna - Bitch Better Have My Money (In Studio Behind The Scenes) (Explicit)
# None
# Accueil YouTube
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
def extractIntFromText(text):
  return int(text.replace(u'\xa0', u''))

def extractGenericLike(soup,classname):
  like_button = soup.findAll("button", { "class" : classname })[0]
  like_count_str = like_button.findAll("span", { "class" : "yt-uix-button-content" })[0].text
  like_count = extractIntFromText(like_count_str)
  return like_count

def getSoupFromUrl(url):
  #Execute q request toward Youtube
  request = requests.get(url)
  #parse the restult of the request
  soup = BeautifulSoup(request.text, 'html.parser')
  return soup

def extractMetricsFromUrl(url):

  soup = getSoupFromUrl(url)
  #GEt the view count
  view_count_str = soup.findAll("div", { "class" : "watch-view-count" })[0].text
  view_count = extractIntFromText(view_count_str)

  #GEt the like count
  like_count = extractGenericLike(soup,"like-button-renderer-like-button")
  #GEt the like count
  dislike_count = extractGenericLike(soup,"like-button-renderer-dislike-button")

  metrics = {}
  metrics['title'] = soup.title.text
  #metrics['view_count'] = view_count
  #metrics['like_count'] = like_count
  #metrics['dislike_count'] = dislike_count
  metrics['indicator'] = 1000.* (like_count - dislike_count) / view_count

  print ('====')
  print ('Handling ' , soup.title.text)
  print ('The like count is', like_count, ' and dislike ', dislike_count)
  print ('Popularity indicator is ' , metrics['indicator'])
  print ('====')
  return metrics


#extractMetricsFromUrl('https://www.youtube.com/watch?v=B3eAMGXFw1o')
#extractMetricsFromUrl('https://www.youtube.com/watch?v=Ao8cGLIMtvg')
#extractMetricsFromUrl('https://www.youtube.com/watch?v=lWA2pjMjpBs')

MAX_PAGE = 2
def getAllMetricsForArtist(artist):
  all_metrics = []
  for i in range(0,MAX_PAGE):
    url = 'https://www.youtube.com/results?search_query='+artist+'&page='+str(i)
    soup = getSoupFromUrl(url)
    tile_links = soup.findAll("a", { "class" : "yt-uix-tile-link" })
    for tile_link in tile_links:
        if 'watch' in tile_link['href']:
          url = 'https://www.youtube.com' + tile_link['href']
          metrics_for_url = extractMetricsFromUrl(url)
          all_metrics.append(metrics_for_url)
  return all_metrics


rihanna = getAllMetricsForArtist('rihanna')
beyonce = getAllMetricsForArtist('beyonce')
# Out:
# ====
# ('Handling ', u'Rihanna - Bitch Better Have My Money (Explicit) - YouTube')
# ('The like count is', 1074729, ' and dislike ', 150559)
# ('Popularity indicator is ', 14.952683542908257)
# ====
# ====
# ('Handling ', u'Rihanna - American Oxygen - YouTube')
# ('The like count is', 457423, ' and dislike ', 31070)
# ('Popularity indicator is ', 7.447927153478696)
# ====
# ====
# ('Handling ', u'Rihanna - Diamonds - YouTube')
# ('The like count is', 2151331, ' and dislike ', 130780)
# ('Popularity indicator is ', 3.039041172644113)
# ====
# ====
# ('Handling ', u'Rihanna And Kanye West And Paul McCartney - FourFiveSeconds - YouTube')
# ('The like count is', 1372851, ' and dislike ', 96584)
# ('Popularity indicator is ', 4.118391492362283)
# ====
# ====
# ('Handling ', u'Rihanna - Man Down - YouTube')
# ('The like count is', 948217, ' and dislike ', 58813)
# ('Popularity indicator is ', 2.4267941491680514)
# ====
# ====
# ('Handling ', u'Rihanna - Pour It Up (Explicit) - YouTube')
# ('The like count is', 682045, ' and dislike ', 237472)
# ('Popularity indicator is ', 2.3737719749428505)
# ====
# ====
# ('Handling ', u'Rihanna - Stay ft. Mikky Ekko - YouTube')
# ('The like count is', 1581077, ' and dislike ', 85853)
# ('Popularity indicator is ', 3.1475966808367923)
# ====
# ====
# ('Handling ', u'Rihanna - Where Have You Been - YouTube')
# ('The like count is', 1228539, ' and dislike ', 58289)
# ('Popularity indicator is ', 3.44922256439224)
# ====
# ====
# ('Handling ', u'Rihanna - Unfaithful - YouTube')
# ('The like count is', 542391, ' and dislike ', 18873)
# ('Popularity indicator is ', 2.1585295251700134)
# ====
# ====
# ('Handling ', u'Rihanna - We Found Love ft. Calvin Harris - YouTube')
# ('The like count is', 1446735, ' and dislike ', 87589)
# ('Popularity indicator is ', 2.45610787767147)
# ====
# ====
# ('Handling ', u'Rihanna - Bitch Better Have My Money (In Studio Behind The Scenes) (Explicit) - YouTube')
# ('The like count is', 123368, ' and dislike ', 4103)
# ('Popularity indicator is ', 8.611721096489113)
# ====
# ====
# ('Handling ', u'Rihanna - Live at Rock in Rio 2015 / FULL SHOW HD - YouTube')
# ('The like count is', 3720, ' and dislike ', 104)
# ('Popularity indicator is ', 6.629473657192411)
# ====
# ====
# ('Handling ', u'Rihanna - Rude Boy - YouTube')
# ('The like count is', 608994, ' and dislike ', 44827)
# ('Popularity indicator is ', 1.6542419583209094)
# ====
# ====
# ('Handling ', u'Rihanna - Umbrella (Orange Version) ft. JAY-Z - YouTube')
# ('The like count is', 554029, ' and dislike ', 28357)
# ('Popularity indicator is ', 2.464144229220427)
# ====
# ====
# ('Handling ', u'Rihanna - What Now (Official) - YouTube')
# ('The like count is', 809509, ' and dislike ', 42672)
# ('Popularity indicator is ', 4.4947737383042385)
# ====
# ====
# ('Handling ', u'Rihanna - Only Girl (In The World) - YouTube')
# ('The like count is', 984531, ' and dislike ', 43767)
# ('Popularity indicator is ', 2.057934269649778)
# ====
# ====
# ('Handling ', u"Rihanna - Don't Stop The Music - YouTube")
# ('The like count is', 366108, ' and dislike ', 13844)
# ('Popularity indicator is ', 1.348400810816592)
# ====
# ====
# ('Handling ', u'Rihanna - S&M - YouTube')
# ('The like count is', 438769, ' and dislike ', 46524)
# ('Popularity indicator is ', 5.367701842359706)
# ====
# ====
# ('Handling ', u'Your Face Sounds Familiar: Myrtle Sarrosa as Rihanna and Nicki Minaj - "Fly" - YouTube')
# ('The like count is', 577, ' and dislike ', 32)
# ('Popularity indicator is ', 7.117112411199331)
# ====
# ====
# ('Handling ', u'Rihanna - Bitch Better Have My Money (Explicit) - YouTube')
# ('The like count is', 1074730, ' and dislike ', 150559)
# ('Popularity indicator is ', 14.952699722489442)
# ====
# ====
# ('Handling ', u'Rihanna - American Oxygen - YouTube')
# ('The like count is', 457423, ' and dislike ', 31070)
# ('Popularity indicator is ', 7.447927153478696)
# ====
# ====
# ('Handling ', u'Rihanna - Diamonds - YouTube')
# ('The like count is', 2151331, ' and dislike ', 130780)
# ('Popularity indicator is ', 3.039041172644113)
# ====
# ====
# ('Handling ', u'Rihanna And Kanye West And Paul McCartney - FourFiveSeconds - YouTube')
# ('The like count is', 1372851, ' and dislike ', 96584)
# ('Popularity indicator is ', 4.118391492362283)
# ====
# ====
# ('Handling ', u'Rihanna - Man Down - YouTube')
# ('The like count is', 948217, ' and dislike ', 58813)
# ('Popularity indicator is ', 2.4267941491680514)
# ====
# ====
# ('Handling ', u'Rihanna - Pour It Up (Explicit) - YouTube')
# ('The like count is', 682046, ' and dislike ', 237472)
# ('Popularity indicator is ', 2.3737773143853604)
# ====
# ====
# ('Handling ', u'Rihanna - Stay ft. Mikky Ekko - YouTube')
# ('The like count is', 1581077, ' and dislike ', 85853)
# ('Popularity indicator is ', 3.1475966808367923)
# ====
# ====
# ('Handling ', u'Rihanna - Where Have You Been - YouTube')
# ('The like count is', 1228539, ' and dislike ', 58289)
# ('Popularity indicator is ', 3.449187440113382)
# ====
# ====
# ('Handling ', u'Rihanna - Unfaithful - YouTube')
# ('The like count is', 542391, ' and dislike ', 18873)
# ('Popularity indicator is ', 2.1585295251700134)
# ====
# ====
# ('Handling ', u'Rihanna - We Found Love ft. Calvin Harris - YouTube')
# ('The like count is', 1446735, ' and dislike ', 87589)
# ('Popularity indicator is ', 2.45610787767147)
# ====
# ====
# ('Handling ', u'Rihanna - Bitch Better Have My Money (In Studio Behind The Scenes) (Explicit) - YouTube')
# ('The like count is', 123368, ' and dislike ', 4103)
# ('Popularity indicator is ', 8.611721096489113)
# ====
# ====
# ('Handling ', u'Rihanna - Live at Rock in Rio 2015 / FULL SHOW HD - YouTube')
# ('The like count is', 3720, ' and dislike ', 104)
# ('Popularity indicator is ', 6.629473657192411)
# ====
# ====
# ('Handling ', u'Rihanna - Rude Boy - YouTube')
# ('The like count is', 608994, ' and dislike ', 44827)
# ('Popularity indicator is ', 1.6542419583209094)
# ====
# ====
# ('Handling ', u'Rihanna - Umbrella (Orange Version) ft. JAY-Z - YouTube')
# ('The like count is', 554030, ' and dislike ', 28357)
# ('Popularity indicator is ', 2.4641489168283446)
# ====
# ====
# ('Handling ', u'Rihanna - What Now (Official) - YouTube')
# ('The like count is', 809509, ' and dislike ', 42672)
# ('Popularity indicator is ', 4.494697020428696)
# ====
# ====
# ('Handling ', u'Rihanna - Only Girl (In The World) - YouTube')
# ('The like count is', 984531, ' and dislike ', 43767)
# ('Popularity indicator is ', 2.057934269649778)
# ====
# ====
# ('Handling ', u"Rihanna - Don't Stop The Music - YouTube")
# ('The like count is', 366108, ' and dislike ', 13844)
# ('Popularity indicator is ', 1.348400810816592)
# ====
# ====
# ('Handling ', u'Rihanna - S&M - YouTube')
# ('The like count is', 438769, ' and dislike ', 46524)
# ('Popularity indicator is ', 5.367701842359706)
# ====
# ====
# ('Handling ', u'Your Face Sounds Familiar: Myrtle Sarrosa as Rihanna and Nicki Minaj - "Fly" - YouTube')
# ('The like count is', 577, ' and dislike ', 32)
# ('Popularity indicator is ', 7.117112411199331)
# ====
# ====
# ('Handling ', u"Naughty Boy - Runnin' (Lose It All) ft. Beyonc\xe9, Arrow Benjamin - YouTube")
# ('The like count is', 397905, ' and dislike ', 14744)
# ('Popularity indicator is ', 4.62578157347247)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - 7/11 - YouTube')
# ('The like count is', 1387425, ' and dislike ', 182098)
# ('Popularity indicator is ', 4.234290223547459)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Drunk in Love (Explicit) ft. JAY Z - YouTube')
# ('The like count is', 1208543, ' and dislike ', 118554)
# ('Popularity indicator is ', 3.29130088319478)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Halo - YouTube')
# ('The like count is', 949762, ' and dislike ', 29822)
# ('Popularity indicator is ', 2.755554850247258)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Single Ladies (Put a Ring on It) - YouTube')
# ('The like count is', 950354, ' and dislike ', 55448)
# ('Popularity indicator is ', 2.0311309759185265)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Run the World (Girls) - YouTube')
# ('The like count is', 936139, ' and dislike ', 141575)
# ('Popularity indicator is ', 2.7827247178635472)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Partition (Explicit Video) - YouTube')
# ('The like count is', 499246, ' and dislike ', 56820)
# ('Popularity indicator is ', 4.317645839289997)
# ====
# ====
# ('Handling ', u'Beyonc\xe9, Ed Sheeran & Gary Clark Jr. Tribute Stevie Wonder - YouTube')
# ('The like count is', 156640, ' and dislike ', 3037)
# ('Popularity indicator is ', 9.18474758940962)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 Greatest Hits New Edition 2015   The Best Of Beyonc\xe9 - YouTube')
# ('The like count is', 5767, ' and dislike ', 218)
# ('Popularity indicator is ', 1.6291488761397657)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Grown Woman - YouTube')
# ('The like count is', 217315, ' and dislike ', 8359)
# ('Popularity indicator is ', 5.892165221550894)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Pretty Hurts - YouTube')
# ('The like count is', 750422, ' and dislike ', 26518)
# ('Popularity indicator is ', 6.335838585395622)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Crazy In Love ft. JAY Z - YouTube')
# ('The like count is', 553393, ' and dislike ', 20647)
# ('Popularity indicator is ', 2.630603663017807)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Best Thing I Never Had - YouTube')
# ('The like count is', 638478, ' and dislike ', 27842)
# ('Popularity indicator is ', 2.875626497956615)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - If I Were A Boy - YouTube')
# ('The like count is', 494775, ' and dislike ', 14262)
# ('Popularity indicator is ', 2.4534210322781003)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Love On Top - YouTube')
# ('The like count is', 750952, ' and dislike ', 28169)
# ('Popularity indicator is ', 3.4957230650524287)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Irreplaceable - YouTube')
# ('The like count is', 412588, ' and dislike ', 14443)
# ('Popularity indicator is ', 2.5919952932966903)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Yonc\xe9 - YouTube')
# ('The like count is', 208698, ' and dislike ', 10753)
# ('Popularity indicator is ', 5.349009167965805)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Countdown - YouTube')
# ('The like count is', 357559, ' and dislike ', 18888)
# ('Popularity indicator is ', 3.6330533611651696)
# ====
# ====
# ('Handling ', u'Coldplay on Collaborating with Beyonce - YouTube')
# ('The like count is', 640, ' and dislike ', 4)
# ('Popularity indicator is ', 61.36034732272069)
# ====
# ====
# ('Handling ', u"Naughty Boy - Runnin' (Lose It All) ft. Beyonc\xe9, Arrow Benjamin - YouTube")
# ('The like count is', 397907, ' and dislike ', 14743)
# ('Popularity indicator is ', 4.625817791523682)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - 7/11 - YouTube')
# ('The like count is', 1387427, ' and dislike ', 182098)
# ('Popularity indicator is ', 4.23429724950842)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Drunk in Love (Explicit) ft. JAY Z - YouTube')
# ('The like count is', 1208544, ' and dislike ', 118554)
# ('Popularity indicator is ', 3.2913039027673476)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Halo - YouTube')
# ('The like count is', 949763, ' and dislike ', 29822)
# ('Popularity indicator is ', 2.755557845610923)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Single Ladies (Put a Ring on It) - YouTube')
# ('The like count is', 950354, ' and dislike ', 55448)
# ('Popularity indicator is ', 2.0311309759185265)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Run the World (Girls) - YouTube')
# ('The like count is', 936140, ' and dislike ', 141575)
# ('Popularity indicator is ', 2.7827282200669163)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Partition (Explicit Video) - YouTube')
# ('The like count is', 499246, ' and dislike ', 56820)
# ('Popularity indicator is ', 4.317645839289997)
# ====
# ====
# ('Handling ', u'Beyonc\xe9, Ed Sheeran & Gary Clark Jr. Tribute Stevie Wonder - YouTube')
# ('The like count is', 156640, ' and dislike ', 3037)
# ('Popularity indicator is ', 9.18474758940962)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 Greatest Hits New Edition 2015   The Best Of Beyonc\xe9 - YouTube')
# ('The like count is', 5767, ' and dislike ', 218)
# ('Popularity indicator is ', 1.6291488761397657)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Grown Woman - YouTube')
# ('The like count is', 217315, ' and dislike ', 8359)
# ('Popularity indicator is ', 5.892165221550894)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Pretty Hurts - YouTube')
# ('The like count is', 750422, ' and dislike ', 26518)
# ('Popularity indicator is ', 6.335838585395622)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Crazy In Love ft. JAY Z - YouTube')
# ('The like count is', 553393, ' and dislike ', 20647)
# ('Popularity indicator is ', 2.630603663017807)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Best Thing I Never Had - YouTube')
# ('The like count is', 638478, ' and dislike ', 27842)
# ('Popularity indicator is ', 2.875626497956615)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - If I Were A Boy - YouTube')
# ('The like count is', 494775, ' and dislike ', 14262)
# ('Popularity indicator is ', 2.4534210322781003)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Love On Top - YouTube')
# ('The like count is', 750952, ' and dislike ', 28169)
# ('Popularity indicator is ', 3.4957230650524287)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Irreplaceable - YouTube')
# ('The like count is', 412588, ' and dislike ', 14443)
# ('Popularity indicator is ', 2.5919952932966903)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Yonc\xe9 - YouTube')
# ('The like count is', 208699, ' and dislike ', 10753)
# ('Popularity indicator is ', 5.34903619066993)
# ====
# ====
# ('Handling ', u'Beyonc\xe9 - Countdown - YouTube')
# ('The like count is', 357559, ' and dislike ', 18888)
# ('Popularity indicator is ', 3.6330533611651696)
# ====
# ====
# ('Handling ', u'Coldplay on Collaborating with Beyonce - YouTube')
# ('The like count is', 640, ' and dislike ', 4)
# ('Popularity indicator is ', 61.36034732272069)
# ====
