# %%
import pandas as pd
import numpy as np
from copy import deepcopy

class DataError(Exception):
    pass

# %%
np.random.seed(88)
nb_projects = 4
group_sizes = [3, 4]
nb_persons = 4 * nb_projects
notation_types = [[50, 49, 1], [21, 20, 20, 19], [50, 25, 25]]
def random_row():
    notation = notation_types[np.random.randint(len(notation_types))]
    row = np.zeros(nb_projects)
    for n, i in zip(notation, np.random.permutation(nb_projects)):
        row[i] = n
    return row
dat = pd.DataFrame(data=[random_row() for i in range(nb_persons)],
                   columns=['Projet_{}'.format(i) for i in range(nb_projects)],
                   index=['Person_{}'.format(i) for i in range(nb_persons)])

# %%
def argsmax(serie, dat):
    '''List of max arguments'''
    m = serie.max()
    ids = []
    for i, s in enumerate(serie):
        if s == m:
            ids.append(i)
    return ids

def pref_proj(dat):
    '''Dictionary where each person points towards a list his/her of preferred projects
    For optimization purposes, we sort the projects from the most demanded to the less demanded'''
    ids_max = dat.apply(lambda s: argsmax(s, dat), axis=1)
    ps_max = {p: list((dat.columns[ids])) for p, ids in zip(dat.index, ids_max)}
    
    #dictionary (project, popularity)
    proj_pop = {p: 0 for p in dat.columns}
    #get for each project, the number of time it is a preferred project
    for ps in ps_max.values():
        for p in ps:
            proj_pop[p] += 1
    # sort the projects from most popular to less popular
    sorted_projs = sorted(proj_pop.items(), key=lambda x: x[1], reverse=True)
    #sort the dictionary values according to this order:
    ps_max = {p: [proj for proj, _ in sorted_projs if proj in p_projs] 
              for p, p_projs in ps_max.items()}
    return ps_max

# %%
def make_groups(dat, group_sizes, verbose=False):
    '''Returns a list of acceptable projects
    Optimization : start with most demanded projects and persons with the fewest preferred projects
    Parameters:
    -----------
    dat : a DataFrame with project notes for each person
    group_sizes : a list of acceptable group sizes
    verbose : activate mode verbose (for understanding the algorithm or debugging)
    Returns:
    --------
    a list of dictionaries of acceptable configurations
    '''
    def v(s, depth):
        '''Print verbose if asked'''
        if verbose:
            print(' ' * depth + str(end=''))
            print(s)
            
    # par personne, liste de projet ayant la meilleure note
    prefs = pref_proj(dat)
    # (convenience) liste des personnes et des projets
    projects = list(dat.columns)
    
    # class persons according to their number of preferred projects
    p_nproj = {p: len(projs) for p, projs in prefs.items()}
    persons = [p for p, _ in sorted(p_nproj.items(), key=lambda x: x[1])]
            
    def insert_person(person, proj, acc):
        if len(acc[proj]) < max(group_sizes):
            new_acc = deepcopy(acc)
            new_acc[proj].append(person)
            return new_acc
        else:
            return None

    def rec(persons, acc, depth=0):
        '''Fonction récursive (non terminale, mais ça devrait passer...)
        Arguments:
        ----------
        persons : liste des personnes restantes à traiter
        acc : dictionnaire (projet, liste des personnes dans le projet) 
              contenant l'état de la solution actuelle
        Résultat:
        ---------
        Liste des solutions valables '''
        # fin de récursion si la liste des personnes est vide
        if not persons:
            # on teste si la solution est valable (taille des groupes)
            if all(len(g) in group_sizes for g in acc.values()):
                return [acc]
            else:
                return []
        # person en cours:
        person = persons[0]
        v('Les projets préférés de {} sont {}'.format(person, prefs[person]), depth)
        sol = []
        # pour chaque projet préféré de chaque personne, on crée un nouvelle branche
        for proj in prefs[person]:
            newacc = insert_person(person, proj, acc)
            # on test s'il a été possible d'ajouter la personne, sinon on ne crée pas de nouvelle branche
            if newacc:
                v('OK il y a de la place dans {}, on ajoute {},'
                  'et on continue la branche !'.format(proj, person), depth)
                # on effectue une union de listes
                sol = sol + rec(persons[1:], newacc, depth=depth+1)
            else:
                v('OH NON, il n\'y a plus de place dans {} pour {},'
                  'en effet il y a déjà : {} ! On s\'arrête là :('.format(proj, person, acc[proj]), depth)
        return sol
    sols = rec(persons, {proj:[] for proj in projects})
    return sols

# %%
def haircut(dat, n):
    ''' Caps all numbers at n'''
    dat_cap = dat.applymap(lambda x: min(n, x))
    return dat_cap

# %%
def algo(dat, group_sizes, cap=50):
    '''Main algorithm (recursive)'''
    # If the data is correct, this should not happen
    # put it there to prevent infinite loop
    if cap == -1:
        raise DataError('Bad data, no solution is possible')
    print("run for cap={}".format(cap))
    sol = make_groups(haircut(dat, cap), group_sizes)    
    if not sol:
        return algo(dat, group_sizes, cap=cap-1)
    return sol

# %%
algo(dat, [0, 3, 4])
# Out:
# run for cap=50
# run for cap=49
# [{'Projet_0': ['Person_10', 'Person_11', 'Person_6', 'Person_5'],
#   'Projet_1': ['Person_15', 'Person_7', 'Person_4', 'Person_8'],
#   'Projet_2': ['Person_12', 'Person_2', 'Person_0', 'Person_9'],
#   'Projet_3': ['Person_14', 'Person_13', 'Person_3', 'Person_1']},
#  {'Projet_0': ['Person_10', 'Person_11', 'Person_6', 'Person_5'],
#   'Projet_1': ['Person_15', 'Person_13', 'Person_4', 'Person_8'],
#   'Projet_2': ['Person_12', 'Person_2', 'Person_0', 'Person_9'],
#   'Projet_3': ['Person_14', 'Person_7', 'Person_3', 'Person_1']},
#  {'Projet_0': ['Person_10', 'Person_11', 'Person_6', 'Person_5'],
#   'Projet_1': ['Person_15', 'Person_7', 'Person_4', 'Person_8'],
#   'Projet_2': ['Person_12', 'Person_14', 'Person_0', 'Person_9'],
#   'Projet_3': ['Person_13', 'Person_2', 'Person_3', 'Person_1']},
#  {'Projet_0': ['Person_10', 'Person_11', 'Person_6', 'Person_5'],
#   'Projet_1': ['Person_15', 'Person_7', 'Person_4', 'Person_8'],
#   'Projet_2': ['Person_12', 'Person_14', 'Person_2', 'Person_9'],
#   'Projet_3': ['Person_13', 'Person_3', 'Person_0', 'Person_1']},
#  {'Projet_0': ['Person_10', 'Person_11', 'Person_6', 'Person_5'],
#   'Projet_1': ['Person_15', 'Person_13', 'Person_4', 'Person_8'],
#   'Projet_2': ['Person_12', 'Person_14', 'Person_0', 'Person_9'],
#   'Projet_3': ['Person_7', 'Person_2', 'Person_3', 'Person_1']},
#  {'Projet_0': ['Person_10', 'Person_11', 'Person_6', 'Person_5'],
#   'Projet_1': ['Person_15', 'Person_13', 'Person_4', 'Person_8'],
#   'Projet_2': ['Person_12', 'Person_14', 'Person_2', 'Person_9'],
#   'Projet_3': ['Person_7', 'Person_3', 'Person_0', 'Person_1']}]

# %%
import requests
from io import StringIO
r = requests.get('https://docs.google.com/spreadsheets/d/1hUWvO8wyEJL-_SkhgpdrwdYiDL7XQdrbTkcp21py8Lw/export?format=csv&id')

# %%
dat_bgd = pd.read_csv(StringIO(r.text), skiprows=1, index_col='Nom', encoding='utf8')
dat_bgd = dat_bgd.loc[:, 'Clustaar':'Plume Labs']
dat_bgd = dat_bgd.fillna(0)
#dat_bgd = dat_bgd.loc[[i for i in dat_bgd.index if isinstance(i, str)], :]

# %%
dat_bgd
# Out:
#                         Clustaar  Kernix Lab  Total  BNP  Amaury  STIF  SFR 1  \
# Nom
# Julien Cloud                   0           0      0    0       0     0      0
# William BENHAIM               50           0      0    0       0     0      0
# Guillaume MOHR                 1           0      0    0       0     0      0
# Jade Lu Dac                    0           0      0   40       0    20      0
# Olivier Large                  0           0      0    0       0     0      0
# Kim Pellegrin                  0          40      0    0       0     0      0
# Malik OUSSALAH                 0          25      0    0       0     0      0
# Catherine Verdier             12           8     10    0       0    12      0
# Cyril Gilbert                  0           0     50    5       0    20      0
# Paul Todorov                  50           4      0    0       0     0      0
# Jeremie Guez                  50          28      0    0       1     0      0
# Aurelien GALICHER              0           0     50    0       0     0      0
# Sophie Corbel                 13          13     13    0       0    12      0
# Jean-Luc Laurent               0           0      0    0       0     0      0
# maxime kubryk                  1           0      0    0       0     0      0
# guillaume fdnz                49           0      0    0       0     0      0
# Florian FIRMIN                 0           0      0    0       0     0      0
# Rachid ALILI                   0          35      0   15       0     0      0
# Cristiana Fiori               15           0      0    0       0     0      0
# Francois Simeonidis           30           0     20   50       0     0      0
# Carl Guichard                  0           0      0    0       0     0      0
# Omar AKIL                      0           0     20   40       0     0      0
# Derrick HO                     0          20     50    0       0     0      0
# Lucas Weissert                50          20      0    0       0     0      0
# Jean-Baptiste Piochaud        25           0     50    0       0     0      0
# Yann Carbonne                 50          10     10    0       0     0      0
# Amine Salem                    0           0      0    0       0     0      0
# Siham Laaroussi               20          10      0    0       0     0      0
# Sedjro SOGLO                  25           0      0    0       0    30      0
# Khalil CHOUROU                 0          30      0   35       0     0      0
#
#                         SFR 2  Alstom  SACEM  FootBar  DCBrain  IPSEN  GrDF  \
# Nom
# Julien Cloud                0       1      0        0       49      0     0
# William BENHAIM             0       0      0        0       26      0     0
# Guillaume MOHR              0       0      0        0       50      0     0
# Jade Lu Dac                 0       0     20        0        0      0    20
# Olivier Large               0       1      0        0       50      0     0
# Kim Pellegrin               0       0     10        0       50      0     0
# Malik OUSSALAH              0       0      0        0        0     50     0
# Catherine Verdier           0       2      0       12       12     10    10
# Cyril Gilbert               0       0      0       25        0      0     0
# Paul Todorov                0       0      0        0        0      4     0
# Jeremie Guez                0       0      0        0        0     21     0
# Aurelien GALICHER           0       0      0        0       40      0     0
# Sophie Corbel               0      12      0        0       12     13     0
# Jean-Luc Laurent            0       0      0        0       20     50     0
# maxime kubryk               0       0      0        0       49      0     0
# guillaume fdnz              0       0      0        0       50      0     0
# Florian FIRMIN              0       5     10        0        5     50     0
# Rachid ALILI                0       0      0        0       50      0     0
# Cristiana Fiori             0       0     25        0        0     50    10
# Francois Simeonidis         0       0      0        0        0      0     0
# Carl Guichard               0      30      0        0        0      0     0
# Omar AKIL                  30       0      0        0        0      0    10
# Derrick HO                  0       0      0        0        0     30     0
# Lucas Weissert              0       0      0        0       30      0     0
# Jean-Baptiste Piochaud      0       0      0        0       25      0     0
# Yann Carbonne               0       0      0        0       10     10     0
# Amine Salem                 0      30      0        0       50     10     0
# Siham Laaroussi             0       0      0        0        0     50     0
# Sedjro SOGLO                0       0     30        0        0      0     0
# Khalil CHOUROU              0      35      0        0        0      0     0
#
#                         Plume Labs
# Nom
# Julien Cloud                    50
# William BENHAIM                 24
# Guillaume MOHR                  49
# Jade Lu Dac                      0
# Olivier Large                   49
# Kim Pellegrin                    0
# Malik OUSSALAH                  25
# Catherine Verdier               12
# Cyril Gilbert                    0
# Paul Todorov                    42
# Jeremie Guez                     0
# Aurelien GALICHER               10
# Sophie Corbel                   12
# Jean-Luc Laurent                30
# maxime kubryk                   50
# guillaume fdnz                   1
# Florian FIRMIN                  30
# Rachid ALILI                     0
# Cristiana Fiori                  0
# Francois Simeonidis              0
# Carl Guichard                   50
# Omar AKIL                        0
# Derrick HO                       0
# Lucas Weissert                   0
# Jean-Baptiste Piochaud           0
# Yann Carbonne                   10
# Amine Salem                     10
# Siham Laaroussi                 20
# Sedjro SOGLO                    15
# Khalil CHOUROU                   0

# %%
import time
now = time.time()

possible_results = algo(dat_bgd, [0,3,4])

later = time.time()
difference = int(later - now)
print str(len(results)) + " different combinations found in " + str(difference) + " seconds"
# Out:
# 923 different combinations found in 1733 seconds

# %% [markdown]
# -------------------------

# %% [markdown]
# affinities is a 2D table that will contains things like:
#     [['Amine Salem', 'Jeremie Guez'],
#      ['Paul Todorov', 'William BENHAIM'],
#      ['Yann Carbonne', 'Lucas Weissert']]

# %%
affinities = []

def addAffinity(person1, person2):
    if [person1, person2] in affinities or [person1, person2] in affinities:
        print "Affinity " + person1 + " <3 " + person2 + " is already there"
    else:
        _without = len(affinities)
        affinities.append([person1, person2])
        _with = len(affinities)
        if (_with - _without) == 1:
            print "Done adding affinity: " + person1 + " <3 " + person2
        elif _with == _without:
            print "Affinity " + person1 + " <3 " + person2 + " was not added"
        else: 
            print "Something went wrong :("

# %%
def cleanTheData_andGetJson(text): #the output is a table of jsons that does not contain empty projects
    #text = text.replace("u'", '\'').replace('\'', '"')
    myJson = json.loads(text)
    for proposition in myJson:
        emptyItems = []
        for project in proposition:
            if len(proposition[project]) == 0:
                emptyItems.append(project)
        for emptyItem in emptyItems:
            proposition.pop(emptyItem)
    return myJson

def projectSatisfiesAffinity(project, affinity): #check if the project contains this affinity
    satisfied = True
    for person in affinity:
        if not person in project:
       #     print person + " is not in " + str(project)
            satisfied = False
       # else:
       #     print person + " is in " + str(project)
            
    return satisfied
    
def getScoreForProposition(proposition, affinities): #get score for proposition, based on how many affinities it does satisfy
    score = 0
    for project in proposition:
        #print "project " + project
        for affinity in affinities:
            #print "affinity " + str(affinity)
            if projectSatisfiesAffinity(proposition[project], affinity):
                score = score + 1
    return score

# %%
def calculate_scores(results, affinities): #generate a 2D table containing [[proposition1, score1], [proposition2, score2]]
    results_str = json.dumps(results)
    propositions = cleanTheData_andGetJson(results_str)
    scores = []
    counter = 0
    for proposition in propositions:
        scores.append([counter, getScoreForProposition(proposition, affinities)])
        counter = counter + 1 
    return scores

# %%
addAffinity('Paul Todorov', 'William BENHAIM')
addAffinity('Yann Carbonne', 'Lucas Weissert') 
addAffinity('Amine Salem', 'Jeremie Guez')
addAffinity('Amine Salem', 'Khalil CHOUROU')
addAffinity('Khalil CHOUROU', 'Carl Guichard')
addAffinity('Jeremie Guez', 'William BENHAIM')
addAffinity('Guillaume MOHR', 'Olivier Large')
addAffinity('Guillaume MOHR', 'Olivier Large')
# Out:
# Done adding affinity: Paul Todorov <3 William BENHAIM
# Done adding affinity: Yann Carbonne <3 Lucas Weissert
# Done adding affinity: Amine Salem <3 Jeremie Guez
# Done adding affinity: Amine Salem <3 Khalil CHOUROU
# Done adding affinity: Khalil CHOUROU <3 Carl Guichard
# Done adding affinity: Jeremie Guez <3 William BENHAIM
# Done adding affinity: Guillaume MOHR <3 Olivier Large
# Affinity Guillaume MOHR <3 Olivier Large is already there

# %%
proposition_to_score = calculate_scores(results, affinities)
scores = pd.DataFrame(proposition_to_score).set_index(0)
best_propositions = scores[scores[1] == np.max(scores[1])]
best_propositions.head()
# Out:
#     1
# 0
# 8   4
# 13  4
# 15  4
# 16  4
# 33  4

# %%
import pprint
# %pprint
results_str = json.dumps(results)
clean_results = cleanTheData_andGetJson(results_str)

pprint.pprint(clean_results[33]) #show the attribution proposition without empty projects
# Out:
# Pretty printing has been turned OFF
# {u'Alstom': [u'Carl Guichard', u'Amine Salem', u'Khalil CHOUROU'],
#  u'BNP': [u'Jade Lu Dac', u'Omar AKIL', u'Francois Simeonidis'],
#  u'Clustaar': [u'Yann Carbonne',
#                u'Paul Todorov',
#                u'William BENHAIM',
#                u'Sedjro SOGLO'],
#  u'DCBrain': [u'Guillaume MOHR',
#               u'Lucas Weissert',
#               u'Olivier Large',
#               u'guillaume fdnz'],
#  u'IPSEN': [u'Siham Laaroussi',
#             u'Florian FIRMIN',
#             u'Derrick HO',
#             u'Cristiana Fiori'],
#  u'Kernix Lab': [u'Rachid ALILI',
#                  u'Jeremie Guez',
#                  u'Kim Pellegrin',
#                  u'Malik OUSSALAH'],
#  u'Plume Labs': [u'Julien Cloud',
#                  u'maxime kubryk',
#                  u'Jean-Luc Laurent',
#                  u'Catherine Verdier'],
#  u'Total': [u'Cyril Gilbert',
#             u'Aurelien GALICHER',
#             u'Jean-Baptiste Piochaud',
#             u'Sophie Corbel']}
