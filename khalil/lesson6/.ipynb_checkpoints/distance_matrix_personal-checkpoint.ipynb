# %%
# read the csv file


#for ville in villes:

# %%
# -*- coding: utf8 -*-
import sys

#sys.setdefaultencoding('utf8')
import pandas as pd
import urllib2
from bs4 import BeautifulSoup
import re
import operator
import urllib2
import json

def distance(ville1,ville2):
    ville1 = re.sub(' ','+',ville1)
    ville2 = re.sub(' ','+',ville2)
    #ville1 = unicode(ville1,errors='replace')
    #ville2 = unicode(ville2,errors='replace')
    print ville1
    print ville2
    url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins="+ville1+"&destinations="+ville2+"&key=AIzaSyB68IYk2dd0noouhy0OxBjzTBqEhKVYzEk" 
    response = urllib2.urlopen(url)
    data = json.load(response)
   
    #print "distance entre ville %s et ville %s est de %s" %(str(ville1),str(ville2),data['rows'][0]['elements'][0]['distance']['text'])
    print data
    #print 
    if (data['rows'][0]['elements'][0]['status'] == "OK"):
        print data['rows'][0]['elements'][0]['distance']['text']
    print '----------------'
    
villes_file = pd.read_csv("villes.csv")
villes = villes_file['Ville']
for ville1 in villes:
    print type(ville1)
    for ville2 in villes:
        distance(ville1,ville2)
# Out:
# <type 'str'>
# Paris
# Paris
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 min', u'value': 0}, u'distance': {u'text': u'1 m', u'value': 0}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Paris, France']}
# 1 m
# ----------------
# Paris
# Marseille
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 1 min', u'value': 25284}, u'distance': {u'text': u'775 km', u'value': 774921}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Marseille, France']}
# 775 km
# ----------------
# Paris
# Lyon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 16 mins', u'value': 15349}, u'distance': {u'text': u'465 km', u'value': 465423}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Lyon, France']}
# 465 km
# ----------------
# Paris
# Toulouse
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 17 mins', u'value': 22590}, u'distance': {u'text': u'679 km', u'value': 679188}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Toulouse, France']}
# 679 km
# ----------------
# Paris
# Nice
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 25 mins', u'value': 30286}, u'distance': {u'text': u'932 km', u'value': 931899}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Nice, France']}
# 932 km
# ----------------
# Paris
# Nantes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 39 mins', u'value': 13125}, u'distance': {u'text': u'385 km', u'value': 384565}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Nantes, France']}
# 385 km
# ----------------
# Paris
# Strasbourg
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 27 mins', u'value': 16026}, u'distance': {u'text': u'491 km', u'value': 491321}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Strasbourg, France']}
# 491 km
# ----------------
# Paris
# Montpellier
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 48 mins', u'value': 24466}, u'distance': {u'text': u'748 km', u'value': 747609}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Montpellier, France']}
# 748 km
# ----------------
# Paris
# Bordeaux
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 25 mins', u'value': 19507}, u'distance': {u'text': u'584 km', u'value': 584315}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Bordeaux, France']}
# 584 km
# ----------------
# Paris
# Lille13
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 9 mins', u'value': 18558}, u'distance': {u'text': u'532 km', u'value': 532287}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u"13 L'Ille, 29340 Riec-sur-B\xe9lon, France"]}
# 532 km
# ----------------
# Paris
# Rennes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 19 mins', u'value': 11949}, u'distance': {u'text': u'353 km', u'value': 352626}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Rennes, France']}
# 353 km
# ----------------
# Paris
# Reims
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 31 mins', u'value': 5479}, u'distance': {u'text': u'144 km', u'value': 144176}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Reims, France']}
# 144 km
# ----------------
# Paris
# Le+Havre
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 19 mins', u'value': 8352}, u'distance': {u'text': u'196 km', u'value': 195995}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Le Havre, France']}
# 196 km
# ----------------
# Paris
# Saint-Étienne
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 57 mins', u'value': 17836}, u'distance': {u'text': u'523 km', u'value': 523490}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-\xc9tienne, France']}
# 523 km
# ----------------
# Paris
# Toulon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 32 mins', u'value': 27143}, u'distance': {u'text': u'839 km', u'value': 838857}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Toulon, France']}
# 839 km
# ----------------
# Paris
# Grenoble
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 11 mins', u'value': 18637}, u'distance': {u'text': u'575 km', u'value': 575422}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Grenoble, France']}
# 575 km
# ----------------
# Paris
# Dijon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 6 mins', u'value': 11183}, u'distance': {u'text': u'315 km', u'value': 315320}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Dijon, France']}
# 315 km
# ----------------
# Paris
# Angers
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 46 mins', u'value': 9958}, u'distance': {u'text': u'296 km', u'value': 295979}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Angers, France']}
# 296 km
# ----------------
# Paris
# Nîmes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 32 mins', u'value': 23534}, u'distance': {u'text': u'713 km', u'value': 712856}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'N\xeemes, France']}
# 713 km
# ----------------
# Paris
# Villeurbanne
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 16 mins', u'value': 15346}, u'distance': {u'text': u'471 km', u'value': 470887}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Villeurbanne, France']}
# 471 km
# ----------------
# Paris
# Saint-Denis
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'29 mins', u'value': 1714}, u'distance': {u'text': u'11.3 km', u'value': 11251}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-Denis, France']}
# 11.3 km
# ----------------
# Paris
# Le+Mans
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 8 mins', u'value': 7667}, u'distance': {u'text': u'208 km', u'value': 208470}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Le Mans, France']}
# 208 km
# ----------------
# Paris
# Clermont-Ferrand
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 54 mins', u'value': 14037}, u'distance': {u'text': u'424 km', u'value': 424428}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Clermont-Ferrand, France']}
# 424 km
# ----------------
# Paris
# Aix-en-Provence
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 53 mins', u'value': 24772}, u'distance': {u'text': u'760 km', u'value': 760449}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Aix-en-Provence, France']}
# 760 km
# ----------------
# Paris
# Brest
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 35 mins', u'value': 20085}, u'distance': {u'text': u'591 km', u'value': 590937}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Brest, France']}
# 591 km
# ----------------
# Paris
# Limoges
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 39 mins', u'value': 13118}, u'distance': {u'text': u'392 km', u'value': 392110}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Limoges, France']}
# 392 km
# ----------------
# Paris
# Tours
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 20 mins', u'value': 8377}, u'distance': {u'text': u'239 km', u'value': 239387}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Tours, France']}
# 239 km
# ----------------
# Paris
# Amiens
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 49 mins', u'value': 6523}, u'distance': {u'text': u'144 km', u'value': 144392}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Amiens, France']}
# 144 km
# ----------------
# Paris
# Perpignan
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 35 mins', u'value': 27303}, u'distance': {u'text': u'848 km', u'value': 848057}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Perpignan, France']}
# 848 km
# ----------------
# Paris
# Metz
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 6 mins', u'value': 11164}, u'distance': {u'text': u'331 km', u'value': 330623}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Metz, France']}
# 331 km
# ----------------
# Paris
# Boulogne-Billancourt
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'29 mins', u'value': 1711}, u'distance': {u'text': u'10.7 km', u'value': 10658}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Boulogne-Billancourt, France']}
# 10.7 km
# ----------------
# Paris
# Besançon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 52 mins', u'value': 13936}, u'distance': {u'text': u'414 km', u'value': 413663}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Besan\xe7on, France']}
# 414 km
# ----------------
# Paris
# Orléans
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 32 mins', u'value': 5493}, u'distance': {u'text': u'133 km', u'value': 132539}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Orl\xe9ans, France']}
# 133 km
# ----------------
# Paris
# Rouen
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 45 mins', u'value': 6295}, u'distance': {u'text': u'135 km', u'value': 135196}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Rouen, France']}
# 135 km
# ----------------
# Paris
# Mulhouse
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 54 mins', u'value': 17635}, u'distance': {u'text': u'537 km', u'value': 536639}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Mulhouse, France']}
# 537 km
# ----------------
# Paris
# Caen
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 33 mins', u'value': 9193}, u'distance': {u'text': u'237 km', u'value': 237405}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Caen, France']}
# 237 km
# ----------------
# Paris
# Saint-Denis
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'29 mins', u'value': 1714}, u'distance': {u'text': u'11.3 km', u'value': 11251}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-Denis, France']}
# 11.3 km
# ----------------
# Paris
# Nancy
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 41 mins', u'value': 13246}, u'distance': {u'text': u'385 km', u'value': 384513}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Nancy, France']}
# 385 km
# ----------------
# Paris
# Argenteuil
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'38 mins', u'value': 2253}, u'distance': {u'text': u'17.9 km', u'value': 17858}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Argenteuil, France']}
# 17.9 km
# ----------------
# Paris
# Saint-Paul
# {u'status': u'OK', u'rows': [{u'elements': [{u'status': u'ZERO_RESULTS'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'St Paul, MN, USA']}
# ----------------
# Paris
# Montreuil
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'22 mins', u'value': 1311}, u'distance': {u'text': u'14.9 km', u'value': 14901}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Montreuil, France']}
# 14.9 km
# ----------------
# Paris
# Roubaix
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 25 mins', u'value': 8722}, u'distance': {u'text': u'236 km', u'value': 235818}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Roubaix, France']}
# 236 km
# ----------------
# Paris
# Tourcoing
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 28 mins', u'value': 8878}, u'distance': {u'text': u'237 km', u'value': 236678}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Tourcoing, France']}
# 237 km
# ----------------
# Paris
# Dunkerque14
# {u'status': u'OK', u'rows': [{u'elements': [{u'status': u'ZERO_RESULTS'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Dunkerque, Punta del Este 20100, Uruguay']}
# ----------------
# Paris
# Nanterre
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'32 mins', u'value': 1904}, u'distance': {u'text': u'12.2 km', u'value': 12150}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Nanterre, France']}
# 12.2 km
# ----------------
# Paris
# Créteil
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'18 mins', u'value': 1086}, u'distance': {u'text': u'13.5 km', u'value': 13537}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Cr\xe9teil, France']}
# 13.5 km
# ----------------
# Paris
# Avignon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 18 mins', u'value': 22708}, u'distance': {u'text': u'690 km', u'value': 689827}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Avignon, France']}
# 690 km
# ----------------
# Paris
# Vitry-sur-Seine
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'23 mins', u'value': 1365}, u'distance': {u'text': u'9.7 km', u'value': 9678}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Vitry-sur-Seine, France']}
# 9.7 km
# ----------------
# Paris
# Poitiers
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 20 mins', u'value': 12020}, u'distance': {u'text': u'340 km', u'value': 340068}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Poitiers, France']}
# 340 km
# ----------------
# Paris
# Courbevoie
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'29 mins', u'value': 1737}, u'distance': {u'text': u'10.3 km', u'value': 10291}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Courbevoie, France']}
# 10.3 km
# ----------------
# Paris
# Fort-de-France
# {u'status': u'OK', u'rows': [{u'elements': [{u'status': u'ZERO_RESULTS'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Fort-de-France Bay, Martinique']}
# ----------------
# Paris
# Versailles
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'43 mins', u'value': 2605}, u'distance': {u'text': u'41.3 km', u'value': 41298}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Versailles, France']}
# 41.3 km
# ----------------
# Paris
# Colombes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'37 mins', u'value': 2244}, u'distance': {u'text': u'13.1 km', u'value': 13090}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Colombes, France']}
# 13.1 km
# ----------------
# Paris
# Asnières-sur-Seine
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'33 mins', u'value': 1992}, u'distance': {u'text': u'9.3 km', u'value': 9272}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Asni\xe8res-sur-Seine, France']}
# 9.3 km
# ----------------
# Paris
# Aulnay-sous-Bois
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'30 mins', u'value': 1823}, u'distance': {u'text': u'24.7 km', u'value': 24713}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Aulnay-sous-Bois, France']}
# 24.7 km
# ----------------
# Paris
# Saint-Pierre
# {u'status': u'OK', u'rows': [{u'elements': [{u'status': u'ZERO_RESULTS'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-Pierre, Reunion']}
# ----------------
# Paris
# Rueil-Malmaison
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'36 mins', u'value': 2142}, u'distance': {u'text': u'14.5 km', u'value': 14465}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Rueil-Malmaison, France']}
# 14.5 km
# ----------------
# Paris
# Pau
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 4 mins', u'value': 25450}, u'distance': {u'text': u'794 km', u'value': 794235}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Pau, France']}
# 794 km
# ----------------
# Paris
# Aubervilliers
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'27 mins', u'value': 1640}, u'distance': {u'text': u'7.6 km', u'value': 7579}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Aubervilliers, France']}
# 7.6 km
# ----------------
# Paris
# Champigny-sur-Marne
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'22 mins', u'value': 1333}, u'distance': {u'text': u'16.2 km', u'value': 16152}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Champigny-sur-Marne, France']}
# 16.2 km
# ----------------
# Paris
# Le+Tampon
# {u'status': u'OK', u'rows': [{u'elements': [{u'status': u'ZERO_RESULTS'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Le Tampon, Reunion']}
# ----------------
# Paris
# Antibes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 17 mins', u'value': 29838}, u'distance': {u'text': u'916 km', u'value': 916375}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Antibes, France']}
# 916 km
# ----------------
# Paris
# Saint-Maur-des-Fossés
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'22 mins', u'value': 1338}, u'distance': {u'text': u'13.0 km', u'value': 13016}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-Maur-des-Foss\xe9s, France']}
# 13.0 km
# ----------------
# Paris
# La+Rochelle
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 27 mins', u'value': 16041}, u'distance': {u'text': u'471 km', u'value': 470890}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'La Rochelle, France']}
# 471 km
# ----------------
# Paris
# Cannes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 12 mins', u'value': 29530}, u'distance': {u'text': u'907 km', u'value': 907445}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Cannes, France']}
# 907 km
# ----------------
# Paris
# Béziers
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 50 mins', u'value': 24576}, u'distance': {u'text': u'757 km', u'value': 756627}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'B\xe9ziers, France']}
# 757 km
# ----------------
# Paris
# Calais
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 50 mins', u'value': 10190}, u'distance': {u'text': u'295 km', u'value': 294684}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Calais, France']}
# 295 km
# ----------------
# Paris
# Saint-Nazaire
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 9 mins', u'value': 14933}, u'distance': {u'text': u'439 km', u'value': 438656}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-Nazaire, France']}
# 439 km
# ----------------
# Paris
# Colmar
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 10 mins', u'value': 18600}, u'distance': {u'text': u'560 km', u'value': 559975}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Colmar, France']}
# 560 km
# ----------------
# Paris
# Drancy
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'31 mins', u'value': 1879}, u'distance': {u'text': u'21.0 km', u'value': 21004}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Drancy, France']}
# 21.0 km
# ----------------
# Paris
# Bourges
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 27 mins', u'value': 8812}, u'distance': {u'text': u'247 km', u'value': 247463}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Bourges, France']}
# 247 km
# ----------------
# Paris
# Mérignac
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 19 mins', u'value': 19163}, u'distance': {u'text': u'590 km', u'value': 589636}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'M\xe9rignac, France']}
# 590 km
# ----------------
# Paris
# Ajaccio
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'15 hours 55 mins', u'value': 57295}, u'distance': {u'text': u'1,124 km', u'value': 1123809}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Ajaccio, France']}
# 1,124 km
# ----------------
# Paris
# Issy-les-Moulineaux
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'26 mins', u'value': 1570}, u'distance': {u'text': u'10.2 km', u'value': 10201}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Issy-les-Moulineaux, France']}
# 10.2 km
# ----------------
# Paris
# Levallois-Perret
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'26 mins', u'value': 1542}, u'distance': {u'text': u'8.0 km', u'value': 8000}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Levallois-Perret, France']}
# 8.0 km
# ----------------
# Paris
# La+Seyne-sur-Mer
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 35 mins', u'value': 27276}, u'distance': {u'text': u'836 km', u'value': 835663}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'La Seyne-sur-Mer, France']}
# 836 km
# ----------------
# Paris
# Quimper
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 20 mins', u'value': 19208}, u'distance': {u'text': u'564 km', u'value': 563556}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Quimper, France']}
# 564 km
# ----------------
# Paris
# Noisy-le-Grand
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'25 mins', u'value': 1475}, u'distance': {u'text': u'19.5 km', u'value': 19521}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Noisy-le-Grand, France']}
# 19.5 km
# ----------------
# Paris
# Valence
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 13 mins', u'value': 18804}, u'distance': {u'text': u'563 km', u'value': 563281}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Valence, France']}
# 563 km
# ----------------
# Paris
# Villeneuve-d'Ascq
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 16 mins', u'value': 8169}, u'distance': {u'text': u'226 km', u'value': 225699}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u"Villeneuve-d'Ascq, France"]}
# 226 km
# ----------------
# Paris
# Neuilly-sur-Seine
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'24 mins', u'value': 1466}, u'distance': {u'text': u'7.4 km', u'value': 7371}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Neuilly-sur-Seine, France']}
# 7.4 km
# ----------------
# Paris
# Antony
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'30 mins', u'value': 1792}, u'distance': {u'text': u'26.7 km', u'value': 26732}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Antony, France']}
# 26.7 km
# ----------------
# Paris
# Vénissieux
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 25 mins', u'value': 15886}, u'distance': {u'text': u'478 km', u'value': 478308}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'V\xe9nissieux, France']}
# 478 km
# ----------------
# Paris
# Cergy
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'48 mins', u'value': 2851}, u'distance': {u'text': u'35.3 km', u'value': 35268}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Cergy, France']}
# 35.3 km
# ----------------
# Paris
# Troyes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 55 mins', u'value': 6919}, u'distance': {u'text': u'179 km', u'value': 178576}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Troyes, France']}
# 179 km
# ----------------
# Paris
# Clichy
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'27 mins', u'value': 1638}, u'distance': {u'text': u'7.9 km', u'value': 7886}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Clichy, France']}
# 7.9 km
# ----------------
# Paris
# Pessac
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 26 mins', u'value': 19574}, u'distance': {u'text': u'597 km', u'value': 596944}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Pessac, France']}
# 597 km
# ----------------
# Paris
# Les+Abymes
# {u'status': u'OK', u'rows': [{u'elements': [{u'status': u'ZERO_RESULTS'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Les Abymes, Guadeloupe']}
# ----------------
# Paris
# Ivry-sur-Seine
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'19 mins', u'value': 1158}, u'distance': {u'text': u'7.5 km', u'value': 7458}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Ivry-sur-Seine, France']}
# 7.5 km
# ----------------
# Paris
# Chambéry
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 12 mins', u'value': 18728}, u'distance': {u'text': u'572 km', u'value': 572412}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Chamb\xe9ry, France']}
# 572 km
# ----------------
# Paris
# Lorient
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 47 mins', u'value': 17228}, u'distance': {u'text': u'503 km', u'value': 503227}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Lorient, France']}
# 503 km
# ----------------
# Paris
# Niort
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 51 mins', u'value': 13878}, u'distance': {u'text': u'412 km', u'value': 411607}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Niort, France']}
# 412 km
# ----------------
# Paris
# Sarcelles
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'46 mins', u'value': 2735}, u'distance': {u'text': u'17.7 km', u'value': 17749}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Sarcelles, France']}
# 17.7 km
# ----------------
# Paris
# Montauban
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 39 mins', u'value': 20350}, u'distance': {u'text': u'624 km', u'value': 624279}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Montauban, France']}
# 624 km
# ----------------
# Paris
# Villejuif
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'24 mins', u'value': 1446}, u'distance': {u'text': u'10.8 km', u'value': 10793}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Villejuif, France']}
# 10.8 km
# ----------------
# Paris
# Saint-Quentin
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 52 mins', u'value': 6701}, u'distance': {u'text': u'171 km', u'value': 170872}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-Quentin, France']}
# 171 km
# ----------------
# Paris
# Hyères
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 51 mins', u'value': 28232}, u'distance': {u'text': u'858 km', u'value': 857516}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Hy\xe8res, France']}
# 858 km
# ----------------
# Paris
# Cayenne
# {u'status': u'OK', u'rows': [{u'elements': [{u'status': u'ZERO_RESULTS'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Cayenne, French Guiana']}
# ----------------
# Paris
# Épinay-sur-Seine
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'36 mins', u'value': 2149}, u'distance': {u'text': u'13.1 km', u'value': 13141}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'\xc9pinay-sur-Seine, France']}
# 13.1 km
# ----------------
# Paris
# Saint-André
# {u'status': u'OK', u'rows': [{u'elements': [{u'status': u'ZERO_RESULTS'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-Andr\xe9, Reunion']}
# ----------------
# Paris
# Beauvais
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 19 mins', u'value': 4732}, u'distance': {u'text': u'85.1 km', u'value': 85081}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Beauvais, France']}
# 85.1 km
# ----------------
# Paris
# Maisons-Alfort
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'17 mins', u'value': 1025}, u'distance': {u'text': u'9.4 km', u'value': 9441}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Maisons-Alfort, France']}
# 9.4 km
# ----------------
# Paris
# Cholet
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 24 mins', u'value': 12267}, u'distance': {u'text': u'356 km', u'value': 356340}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Cholet, France']}
# 356 km
# ----------------
# Paris
# Meaux
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'46 mins', u'value': 2737}, u'distance': {u'text': u'54.6 km', u'value': 54639}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Meaux, France']}
# 54.6 km
# ----------------
# Paris
# Chelles
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'37 mins', u'value': 2205}, u'distance': {u'text': u'27.0 km', u'value': 27001}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Chelles, France']}
# 27.0 km
# ----------------
# Paris
# Pantin
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'27 mins', u'value': 1648}, u'distance': {u'text': u'8.0 km', u'value': 7954}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Pantin, France']}
# 8.0 km
# ----------------
# Paris
# Fontenay-sous-Bois
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'27 mins', u'value': 1595}, u'distance': {u'text': u'16.5 km', u'value': 16463}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Fontenay-sous-Bois, France']}
# 16.5 km
# ----------------
# Paris
# La+Roche-sur-Yon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 53 mins', u'value': 13984}, u'distance': {u'text': u'425 km', u'value': 425114}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'La Roche-sur-Yon, France']}
# 425 km
# ----------------
# Paris
# Bondy
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'23 mins', u'value': 1383}, u'distance': {u'text': u'18.1 km', u'value': 18072}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'93140 Bondy, France']}
# 18.1 km
# ----------------
# Paris
# Vannes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 25 mins', u'value': 15884}, u'distance': {u'text': u'463 km', u'value': 463053}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Vannes, France']}
# 463 km
# ----------------
# Paris
# Saint-Louis
# {u'status': u'OK', u'rows': [{u'elements': [{u'status': u'ZERO_RESULTS'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'St Louis, MO, USA']}
# ----------------
# Paris
# Fréjus
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 51 mins', u'value': 28270}, u'distance': {u'text': u'874 km', u'value': 873712}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Fr\xe9jus, France']}
# 874 km
# ----------------
# Paris
# Arles
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 43 mins', u'value': 24196}, u'distance': {u'text': u'745 km', u'value': 744508}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Arles, France']}
# 745 km
# ----------------
# Paris
# Clamart
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'35 mins', u'value': 2104}, u'distance': {u'text': u'11.0 km', u'value': 10977}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Clamart, France']}
# 11.0 km
# ----------------
# Paris
# Évry
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'38 mins', u'value': 2256}, u'distance': {u'text': u'37.5 km', u'value': 37469}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'\xc9vry, France']}
# 37.5 km
# ----------------
# Paris
# Le+Blanc-Mesnil
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'31 mins', u'value': 1871}, u'distance': {u'text': u'22.6 km', u'value': 22612}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Le Blanc-Mesnil, France']}
# 22.6 km
# ----------------
# Paris
# Narbonne
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 5 mins', u'value': 25481}, u'distance': {u'text': u'787 km', u'value': 786851}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Narbonne, France']}
# 787 km
# ----------------
# Paris
# Sartrouville
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'46 mins', u'value': 2772}, u'distance': {u'text': u'20.7 km', u'value': 20745}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'78500 Sartrouville, France']}
# 20.7 km
# ----------------
# Paris
# Grasse
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 17 mins', u'value': 29790}, u'distance': {u'text': u'918 km', u'value': 918083}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Grasse, France']}
# 918 km
# ----------------
# Paris
# Annecy
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 9 mins', u'value': 18541}, u'distance': {u'text': u'559 km', u'value': 559460}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Annecy, France']}
# 559 km
# ----------------
# Paris
# Laval
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 37 mins', u'value': 9440}, u'distance': {u'text': u'281 km', u'value': 280692}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Laval, France']}
# 281 km
# ----------------
# Paris
# Belfort
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 30 mins', u'value': 16218}, u'distance': {u'text': u'500 km', u'value': 500404}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Belfort, France']}
# 500 km
# ----------------
# Paris
# Vincennes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'22 mins', u'value': 1297}, u'distance': {u'text': u'10.0 km', u'value': 10023}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Vincennes, France']}
# 10.0 km
# ----------------
# Paris
# Charleville-Mézières
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 23 mins', u'value': 8602}, u'distance': {u'text': u'233 km', u'value': 233379}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Charleville-M\xe9zi\xe8res, France']}
# 233 km
# ----------------
# Paris
# Évreux
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 26 mins', u'value': 5139}, u'distance': {u'text': u'95.7 km', u'value': 95699}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'\xc9vreux, France']}
# 95.7 km
# ----------------
# Paris
# Sevran
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'39 mins', u'value': 2313}, u'distance': {u'text': u'25.6 km', u'value': 25623}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Sevran, France']}
# 25.6 km
# ----------------
# Paris
# Albi
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 30 mins', u'value': 23421}, u'distance': {u'text': u'699 km', u'value': 698681}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Albi, France']}
# 699 km
# ----------------
# Paris
# Montrouge
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'22 mins', u'value': 1298}, u'distance': {u'text': u'5.9 km', u'value': 5935}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Montrouge, France']}
# 5.9 km
# ----------------
# Paris
# Bobigny
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'28 mins', u'value': 1683}, u'distance': {u'text': u'21.6 km', u'value': 21563}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Bobigny, France']}
# 21.6 km
# ----------------
# Paris
# Martigues
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 5 mins', u'value': 25488}, u'distance': {u'text': u'782 km', u'value': 782061}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Martigues, France']}
# 782 km
# ----------------
# Paris
# Saint-Ouen
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'27 mins', u'value': 1646}, u'distance': {u'text': u'7.1 km', u'value': 7097}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-Ouen, France']}
# 7.1 km
# ----------------
# Paris
# Brive-la-Gaillarde
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 29 mins', u'value': 16127}, u'distance': {u'text': u'481 km', u'value': 481416}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Brive-la-Gaillarde, France']}
# 481 km
# ----------------
# Paris
# Suresnes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'35 mins', u'value': 2084}, u'distance': {u'text': u'12.8 km', u'value': 12786}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Suresnes, France']}
# 12.8 km
# ----------------
# Paris
# Carcassonne
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 3 mins', u'value': 25380}, u'distance': {u'text': u'770 km', u'value': 769661}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Carcassonne, France']}
# 770 km
# ----------------
# Paris
# Cagnes-sur-Mer
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 17 mins', u'value': 29849}, u'distance': {u'text': u'921 km', u'value': 920997}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Cagnes-sur-Mer, France']}
# 921 km
# ----------------
# Paris
# Corbeil-Essonnes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'42 mins', u'value': 2528}, u'distance': {u'text': u'41.5 km', u'value': 41499}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Corbeil-Essonnes, France']}
# 41.5 km
# ----------------
# Paris
# Saint-Brieuc
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 13 mins', u'value': 15159}, u'distance': {u'text': u'449 km', u'value': 448710}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-Brieuc, France']}
# 449 km
# ----------------
# Paris
# Blois
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 54 mins', u'value': 6842}, u'distance': {u'text': u'185 km', u'value': 184798}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Blois, France']}
# 185 km
# ----------------
# Paris
# Bayonne
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 55 mins', u'value': 24926}, u'distance': {u'text': u'770 km', u'value': 770193}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Bayonne, France']}
# 770 km
# ----------------
# Paris
# Aubagne
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 10 mins', u'value': 25770}, u'distance': {u'text': u'794 km', u'value': 793642}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Aubagne, France']}
# 794 km
# ----------------
# Paris
# Châlons-en-Champagne
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 53 mins', u'value': 6797}, u'distance': {u'text': u'188 km', u'value': 187566}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Ch\xe2lons-en-Champagne, France']}
# 188 km
# ----------------
# Paris
# Meudon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'29 mins', u'value': 1727}, u'distance': {u'text': u'12.0 km', u'value': 11998}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Meudon, France']}
# 12.0 km
# ----------------
# Paris
# Châteauroux
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 39 mins', u'value': 9514}, u'distance': {u'text': u'271 km', u'value': 270827}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Ch\xe2teauroux, France']}
# 271 km
# ----------------
# Paris
# Saint-Malo
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 1 min', u'value': 14452}, u'distance': {u'text': u'417 km', u'value': 417116}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'St-Malo, France']}
# 417 km
# ----------------
# Paris
# Chalon-sur-Saône
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 11 mins', u'value': 11446}, u'distance': {u'text': u'340 km', u'value': 340492}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Chalon-sur-Sa\xf4ne, France']}
# 340 km
# ----------------
# Paris
# Sète
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 3 mins', u'value': 25360}, u'distance': {u'text': u'758 km', u'value': 757794}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'S\xe8te, France']}
# 758 km
# ----------------
# Paris
# Puteaux
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'28 mins', u'value': 1677}, u'distance': {u'text': u'10.3 km', u'value': 10252}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Puteaux, France']}
# 10.3 km
# ----------------
# Paris
# Alfortville
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'17 mins', u'value': 1043}, u'distance': {u'text': u'9.6 km', u'value': 9571}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Alfortville, France']}
# 9.6 km
# ----------------
# Paris
# Salon-de-Provence
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 35 mins', u'value': 23706}, u'distance': {u'text': u'726 km', u'value': 726059}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Salon-de-Provence, France']}
# 726 km
# ----------------
# Paris
# Massy
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'31 mins', u'value': 1832}, u'distance': {u'text': u'24.6 km', u'value': 24621}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Massy, France']}
# 24.6 km
# ----------------
# Paris
# Mantes-la-Jolie
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'57 mins', u'value': 3417}, u'distance': {u'text': u'53.3 km', u'value': 53271}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Mantes-la-Jolie, France']}
# 53.3 km
# ----------------
# Paris
# Bastia
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'14 hours 42 mins', u'value': 52945}, u'distance': {u'text': u'1,126 km', u'value': 1125667}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Bastia, France']}
# 1,126 km
# ----------------
# Paris
# Vaulx-en-Velin
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 15 mins', u'value': 15320}, u'distance': {u'text': u'470 km', u'value': 469769}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Vaulx-en-Velin, France']}
# 470 km
# ----------------
# Paris
# Saint-Herblain
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 37 mins', u'value': 13037}, u'distance': {u'text': u'391 km', u'value': 390840}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Saint-Herblain, France']}
# 391 km
# ----------------
# Paris
# Le+Cannet
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 8 mins', u'value': 29255}, u'distance': {u'text': u'907 km', u'value': 906606}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Le Cannet, France']}
# 907 km
# ----------------
# Paris
# Valenciennes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 10 mins', u'value': 7782}, u'distance': {u'text': u'212 km', u'value': 211673}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Valenciennes, France']}
# 212 km
# ----------------
# Paris
# Istres
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 56 mins', u'value': 24988}, u'distance': {u'text': u'754 km', u'value': 754368}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Istres, France']}
# 754 km
# ----------------
# Paris
# Gennevilliers
# ...
# 205 km
# ----------------
# Nice
# Lyon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 19 mins', u'value': 15546}, u'distance': {u'text': u'471 km', u'value': 470657}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Lyon, France']}
# 471 km
# ----------------
# Nice
# Toulouse
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 15 mins', u'value': 18900}, u'distance': {u'text': u'560 km', u'value': 560073}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Toulouse, France']}
# 560 km
# ----------------
# Nice
# Nice
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 min', u'value': 0}, u'distance': {u'text': u'1 m', u'value': 0}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Nice, France']}
# 1 m
# ----------------
# Nice
# Nantes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'10 hours 6 mins', u'value': 36361}, u'distance': {u'text': u'1,143 km', u'value': 1142581}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Nantes, France']}
# 1,143 km
# ----------------
# Nice
# Strasbourg
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 13 mins', u'value': 29570}, u'distance': {u'text': u'785 km', u'value': 784519}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Strasbourg, France']}
# 785 km
# ----------------
# Nice
# Montpellier
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'3 hours 18 mins', u'value': 11907}, u'distance': {u'text': u'326 km', u'value': 325802}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Montpellier, France']}
# 326 km
# ----------------
# Nice
# Bordeaux
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 18 mins', u'value': 26250}, u'distance': {u'text': u'802 km', u'value': 802270}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Bordeaux, France']}
# 802 km
# ----------------
# Nice
# Lille13
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'12 hours 2 mins', u'value': 43304}, u'distance': {u'text': u'1,341 km', u'value': 1340642}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u"13 L'Ille, 29340 Riec-sur-B\xe9lon, France"]}
# 1,341 km
# ----------------
# Nice
# Rennes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'10 hours 39 mins', u'value': 38312}, u'distance': {u'text': u'1,207 km', u'value': 1206868}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Rennes, France']}
# 1,207 km
# ----------------
# Nice
# Reims
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 22 mins', u'value': 30149}, u'distance': {u'text': u'955 km', u'value': 955180}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Reims, France']}
# 955 km
# ----------------
# Nice
# Le+Havre
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'10 hours 9 mins', u'value': 36541}, u'distance': {u'text': u'1,123 km', u'value': 1122678}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Le Havre, France']}
# 1,123 km
# ----------------
# Nice
# Saint-Étienne
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 35 mins', u'value': 16523}, u'distance': {u'text': u'490 km', u'value': 489778}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Saint-\xc9tienne, France']}
# 490 km
# ----------------
# Nice
# Toulon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 38 mins', u'value': 5886}, u'distance': {u'text': u'150 km', u'value': 149516}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Toulon, France']}
# 150 km
# ----------------
# Nice
# Grenoble
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 14 mins', u'value': 15238}, u'distance': {u'text': u'463 km', u'value': 462769}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Grenoble, France']}
# 463 km
# ----------------
# Nice
# Dijon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 5 mins', u'value': 21897}, u'distance': {u'text': u'662 km', u'value': 661771}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Dijon, France']}
# 662 km
# ----------------
# Nice
# Angers
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'9 hours 21 mins', u'value': 33636}, u'distance': {u'text': u'1,063 km', u'value': 1062549}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Angers, France']}
# 1,063 km
# ----------------
# Nice
# Nîmes
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'2 hours 50 mins', u'value': 10182}, u'distance': {u'text': u'279 km', u'value': 278715}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'N\xeemes, France']}
# 279 km
# ----------------
# Nice
# Villeurbanne
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 21 mins', u'value': 15672}, u'distance': {u'text': u'475 km', u'value': 474800}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Villeurbanne, France']}
# 475 km
# ----------------
# Nice
# Saint-Denis
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 35 mins', u'value': 30882}, u'distance': {u'text': u'945 km', u'value': 945025}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Saint-Denis, France']}
# 945 km
# ----------------
# Nice
# Le+Mans
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'9 hours 24 mins', u'value': 33850}, u'distance': {u'text': u'1,049 km', u'value': 1048706}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Le Mans, France']}
# 1,049 km
# ----------------
# Nice
# Clermont-Ferrand
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'5 hours 51 mins', u'value': 21055}, u'distance': {u'text': u'631 km', u'value': 630880}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Clermont-Ferrand, France']}
# 631 km
# ----------------
# Nice
# Aix-en-Provence
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 hour 49 mins', u'value': 6524}, u'distance': {u'text': u'176 km', u'value': 176143}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Aix-en-Provence, France']}
# 176 km
# ----------------
# Nice
# Brest
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'12 hours 51 mins', u'value': 46272}, u'distance': {u'text': u'1,437 km', u'value': 1436966}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Brest, France']}
# 1,437 km
# ----------------
# Nice
# Limoges
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 40 mins', u'value': 27583}, u'distance': {u'text': u'847 km', u'value': 847476}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Limoges, France']}
# 847 km
# ----------------
# Nice
# Tours
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 29 mins', u'value': 30518}, u'distance': {u'text': u'955 km', u'value': 954630}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Tours, France']}
# 955 km
# ----------------
# Nice
# Amiens
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'9 hours 56 mins', u'value': 35730}, u'distance': {u'text': u'1,075 km', u'value': 1075463}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Amiens, France']}
# 1,075 km
# ----------------
# Nice
# Perpignan
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'4 hours 28 mins', u'value': 16070}, u'distance': {u'text': u'474 km', u'value': 474408}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Perpignan, France']}
# 474 km
# ----------------
# Nice
# Metz
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 13 mins', u'value': 29606}, u'distance': {u'text': u'923 km', u'value': 923251}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Metz, France']}
# 923 km
# ----------------
# Nice
# Boulogne-Billancourt
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 23 mins', u'value': 30164}, u'distance': {u'text': u'933 km', u'value': 932703}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Boulogne-Billancourt, France']}
# 933 km
# ----------------
# Nice
# Besançon
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'6 hours 34 mins', u'value': 23615}, u'distance': {u'text': u'721 km', u'value': 720904}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Besan\xe7on, France']}
# 721 km
# ----------------
# Nice
# Orléans
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'8 hours 11 mins', u'value': 29444}, u'distance': {u'text': u'915 km', u'value': 914902}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Orl\xe9ans, France']}
# 915 km
# ----------------
# Nice
# Rouen
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'9 hours 35 mins', u'value': 34484}, u'distance': {u'text': u'1,062 km', u'value': 1061878}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Rouen, France']}
# 1,062 km
# ----------------
# Nice
# Mulhouse
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'7 hours 23 mins', u'value': 26556}, u'distance': {u'text': u'686 km', u'value': 685525}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Mulhouse, France']}
# 686 km
# ----------------
# Nice
# Caen
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'10 hours 23 mins', u'value': 37382}, u'distance': {u'text': u'1,164 km', u'value': 1164087}, u'status': u'OK'}]}], u'origin_addresses': [u'Nice, France'], u'destination_addresses': [u'Caen, France']}
# 1,164 km
# ----------------
# Nice
# Saint-Denis
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e700ee539add> in <module>()
#      34     print type(ville1)
#      35     for ville2 in villes:
# ---> 36         distance(ville1,ville2)
#      37
#
# <ipython-input-2-e700ee539add> in distance(ville1, ville2)
#      19     print ville2
#      20     url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins="+ville1+"&destinations="+ville2+"&key=AIzaSyB68IYk2dd0noouhy0OxBjzTBqEhKVYzEk"
# ---> 21     response = urllib2.urlopen(url)
#      22     data = json.load(response)
#      23
#
# /home/khalil/anaconda/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /home/khalil/anaconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     429             req = meth(req)
#     430
# --> 431         response = self._open(req, data)
#     432
#     433         # post-process response
#
# /home/khalil/anaconda/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     447         protocol = req.get_type()
#     448         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 449                                   '_open', req)
#     450         if result:
#     451             return result
#
# /home/khalil/anaconda/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     407             func = getattr(handler, meth_name)
#     408
# --> 409             result = func(*args)
#     410             if result is not None:
#     411                 return result
#
# /home/khalil/anaconda/lib/python2.7/urllib2.pyc in https_open(self, req)
#    1238         def https_open(self, req):
#    1239             return self.do_open(httplib.HTTPSConnection, req,
# -> 1240                 context=self._context)
#    1241
#    1242         https_request = AbstractHTTPHandler.do_request_
#
# /home/khalil/anaconda/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1192
#    1193         try:
# -> 1194             h.request(req.get_method(), req.get_selector(), req.data, headers)
#    1195         except socket.error, err: # XXX what error?
#    1196             h.close()
#
# /home/khalil/anaconda/lib/python2.7/httplib.pyc in request(self, method, url, body, headers)
#    1051     def request(self, method, url, body=None, headers={}):
#    1052         """Send a complete request to the server."""
# -> 1053         self._send_request(method, url, body, headers)
#    1054
#    1055     def _set_content_length(self, body, method):
#
# /home/khalil/anaconda/lib/python2.7/httplib.pyc in _send_request(self, method, url, body, headers)
#    1091         for hdr, value in headers.iteritems():
#    1092             self.putheader(hdr, value)
# -> 1093         self.endheaders(body)
#    1094
#    1095     def getresponse(self, buffering=False):
#
# /home/khalil/anaconda/lib/python2.7/httplib.pyc in endheaders(self, message_body)
#    1047         else:
#    1048             raise CannotSendHeader()
# -> 1049         self._send_output(message_body)
#    1050
#    1051     def request(self, method, url, body=None, headers={}):
#
# /home/khalil/anaconda/lib/python2.7/httplib.pyc in _send_output(self, message_body)
#     891             msg += message_body
#     892             message_body = None
# --> 893         self.send(msg)
#     894         if message_body is not None:
#     895             #message_body was not a string (i.e. it is a file) and
#
# /home/khalil/anaconda/lib/python2.7/httplib.pyc in send(self, data)
#     853         if self.sock is None:
#     854             if self.auto_open:
# --> 855                 self.connect()
#     856             else:
#     857                 raise NotConnected()
#
# /home/khalil/anaconda/lib/python2.7/httplib.pyc in connect(self)
#    1272
#    1273             self.sock = self._context.wrap_socket(self.sock,
# -> 1274                                                   server_hostname=server_hostname)
#    1275
#    1276     __all__.append("HTTPSConnection")
#
# /home/khalil/anaconda/lib/python2.7/ssl.pyc in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     350                          suppress_ragged_eofs=suppress_ragged_eofs,
#     351                          server_hostname=server_hostname,
# --> 352                          _context=self)
#     353
#     354     def set_npn_protocols(self, npn_protocols):
#
# /home/khalil/anaconda/lib/python2.7/ssl.pyc in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context)
#     577                         # non-blocking
#     578                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 579                     self.do_handshake()
#     580
#     581             except (OSError, ValueError):
#
# /home/khalil/anaconda/lib/python2.7/ssl.pyc in do_handshake(self, block)
#     806             if timeout == 0.0 and block:
#     807                 self.settimeout(None)
# --> 808             self._sslobj.do_handshake()
#     809         finally:
#     810             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
# Out:
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'12 hours 25 mins', u'value': 44700}, u'distance': {u'text': u'1,300 km', u'value': 1300401}, u'status': u'OK'}]}], u'origin_addresses': [u'Seattle, WA, USA'], u'destination_addresses': [u'San Francisco, CA, USA']}

# %%
# Out:
# {u'status': u'OK', u'rows': [{u'elements': [{u'duration': {u'text': u'1 min', u'value': 0}, u'distance': {u'text': u'1 m', u'value': 0}, u'status': u'OK'}]}], u'origin_addresses': [u'Paris, France'], u'destination_addresses': [u'Paris, France']}

# %%
# Out:
# OK
